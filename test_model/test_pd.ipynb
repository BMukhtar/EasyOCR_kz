# %%
import pandas as pd

df = pd.read_csv("../../synthtiger_kz/results/test_v7/images/0/labels.csv", sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)

# %%
df.head()
# Out:
#   filename                   words
# 0    1.jpg                   бытыс
# 1    6.jpg   меншіктелін мұздақтау
# 2    0.jpg    майлаусыз тапсырысты
# 3    2.jpg  өнерлеу ұмсындыр төбет
# 4    5.jpg  аталу термодинамикалық

# %%
# check whether some word has comma
df[df['words'].str.contains('"')]
# Out:
#       filename                       words
# 53      65.jpg   "себепші, препараттардың"
# 90      80.jpg  "кескінде жалғызда керме,"
# 250    262.jpg                "шіміркент,"
# 385    389.jpg              "шұқши, ессіз"
# 409    419.jpg             "илен, сүмірею"
# 453    478.jpg          "Үшті 18570 тоба,"
# 470    464.jpg        "азаю ықшамда озаң,"
# 510    520.jpg           "-7914 тебіндет,"
# 535    544.jpg                "тәлімсуші,"
# 575    571.jpg       "#сайдауыл жылшылық,"
# 626    628.jpg      "аштық, антисептиктік"
# 627    632.jpg                 "бүтіндел,"
# 675    689.jpg      "жиңангездік, айтарым"
# 732    718.jpg               "мұрагерсіз,"
# 1227  1250.jpg           "алатын тасырақ,"
# 1230  1229.jpg       "БІТЕ ақылдасу ісір,"
# 1267  1271.jpg        "бұлауда) бұлдырық,"
# 1317  1309.jpg        "жатуы, цензор т.б."
# 1363  1372.jpg          "датқа: ардақтау,"
# 1461  1460.jpg   "принципті-мәди еліптес,"
# 1508  1516.jpg    "кестеге машиналандыру,"
# ...
